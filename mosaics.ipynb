# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 300

# %%
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 --bw 0.1
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 --bw 0.5
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 --bw 1
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 --bw 5
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 --bw 10
# Out:
# Finish computing 200 msts in 0.658
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# Finish computing 200 msts in 0.654
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# Finish computing 200 msts in 0.66
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# Finish computing 200 msts in 0.674
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# Finish computing 200 msts in 0.651
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0

# %%
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 
# %run I_x/noise.py --name 'circle' --n 220 --n_subsets 260 
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 --noise 'uni' --n_noise 20
# Out:
# Finish computing 200 msts in 0.685
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# Finish computing 220 msts in 0.833
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# Finish computing 220 msts in 0.803
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01

# %%
# %run I_x/noise.py --name 'circle' --n 250 --n_subsets 260 
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 260 --noise 'uni' --n_noise 50
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 360 --noise 'uni' --n_noise 100
# Out:
# Finish computing 250 msts in 1.044
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# Finish computing 250 msts in 1.077
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# Finish computing 300 msts in 1.506
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01

# %%
# %run I_x/noise.py --name 'circle' --n 200 --n_subsets 500 --noise 'uni' --n_noise 200 --viz_pts
# Out:
# Finish computing 400 msts in 3.28
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
#  300: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.04 4) subslice 0.03

# %%
# %run I_x/noise.py --name 'blob' --n 100 --n_subsets 260 --d 2 
# %run I_x/noise.py --name 'blob' --n 100 --n_subsets 260 --d 5
# %run I_x/noise.py --name 'blob' --n 100 --n_subsets 260 --d 20
# Out:
# Finish computing 200 msts in 0.677
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01
# Finish computing 200 msts in 0.657
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01
# Finish computing 200 msts in 0.649
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01

# %%
# %run I_x/noise.py --name 'blob' --n 100 --n_subsets 260 --d 20 --num
# %run I_x/noise.py --name 'blob' --n 100 --n_subsets 260 --d 50
# %run I_x/noise.py --name 'blob' --n 250 --n_subsets 550 --d 50
# Out:
# Finish computing 200 msts in 0.661
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# Finish computing 200 msts in 0.645
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# Finish computing 500 msts in 4.389
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
#  300: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.04 4) subslice 0.03
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.04 4) subslice 0.03
#  400: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.05 4) subslice 0.04

# %%
# %run I_x/noise.py --name 'blob' --n 250 --n_subsets 550 --d 2
# %run I_x/noise.py --name 'blob' --n 250 --n_subsets 550 --d 5
# %run I_x/noise.py --name 'blob' --n 250 --n_subsets 550 --d 10
# Out:
# Finish computing 500 msts in 4.919
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.03 4) subslice 0.01
#  300: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.07 4) subslice 0.05
#  400: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.05 4) subslice 0.04
# Finish computing 500 msts in 4.991
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01
#  300: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.07 4) subslice 0.05
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.03 4) subslice 0.01
#  400: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.06 4) subslice 0.05
# Finish computing 500 msts in 4.987
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
#  300: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.07 4) subslice 0.05
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# ...

# %%
# %run I_x/noise.py --name 'moon' --n 100 --n_subsets 260 
# %run I_x/noise.py --name 'circle' --n 100 --n_subsets 260
# Out:
# Finish computing 100 msts in 0.175
# Finish computing 100 msts in 0.173

# %%
# %run I_x/noise.py --name 'blob' --n 200 --n_subsets 260 
# %run I_x/noise.py --name 'aniso' --n 200 --n_subsets 260
# Out:
# Finish computing 200 msts in 0.819
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# Finish computing 200 msts in 0.655
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0

# %%
# %run I_x/noise.py --name 'circle' --n 50 --n_subsets 260 --noise 'uni' --n_noise 1
# Out:
# Finish computing 51 msts in 0.05

# %%
# %run I_x/noise.py --name 'circle' --n 50 --n_subsets 260 --noise 'uni' --n_noise 50
# Out:
# Finish computing 100 msts in 0.171

# %%
# %run I_x/noise.py --name 'circle' --n 100 --n_subsets 260
# Out:
# Finish computing 100 msts in 0.171

# %%
# %run I_x/noise.py --viz_pts --n 200 --n_subsets 260 --noise 'uni' --n_noise 1
# Out:
# Finish computing 201 msts in 0.706
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01

# %%
# %run I_x/noise.py --n 200 --n_subsets 260 --noise 'uni' --n_noise 50
# Out:
# Finish computing 250 msts in 1.077
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.01
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01

# %%
# %run I_x/noise.py --n 200 --n_subsets 300 --noise 'uni' --n_noise 100
# Out:
# Finish computing 300 msts in 1.862
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0

# %%
# %run I_x/noise.py --viz_pts --n 100 --n_subsets 260 --noise 'uni' --n_noise 50
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 150 msts in 0.402
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# %run I_x/noise.py --viz --n_subsets 100
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/graph_tool/all.py:40: RuntimeWarning: Error importing draw module, proceeding nevertheless: /home/cai.507/anaconda3/lib/python3.6/site-packages/graph_tool/draw/libgraph_tool_draw.so: undefined symbol: _ZN5Cairo7Context9show_textERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE
#   warnings.warn(msg, RuntimeWarning)
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 100 msts in 0.174
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# ...

# %%
# %run I_x/noise.py --viz --n 200 --n_subsets 210
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 200 msts in 0.667
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# %run I_x/noise.py --viz --n 200 --n_subsets 260 --noise 'uni' --n_noise 50
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 250 msts in 1.023
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# %run I_x/noise.py --n 200 --n_subsets 260 --name 'blob'
# Out:
# Finish computing 200 msts in 0.917
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0

# %%
# %run I_x/noise.py --n 200 --n_subsets 260 --name 'circle'
# Out:
# Finish computing 200 msts in 0.686
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0

# %%
# %run I_x/noise.py --n 200 --n_subsets 360 --name 'circle' --noise 'uni' --n_noise 1
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 201 msts in 0.666
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# %run I_x/noise.py --n 200 --n_subsets 360 --name 'circle' --noise 'uni' --n_noise 20
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 220 msts in 1.068
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# %run I_x/noise.py --n 200 --n_subsets 360 --name 'circle' --noise 'uni' --n_noise 1
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 201 msts in 1.051
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
#  200: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.02 4) subslice 0.01
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# %run I_x/noise.py --n 200 --n_subsets 260 --name 'aniso'
# Out:
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# Finish computing 200 msts in 0.735
#  100: 1) get_subgraph 0.0 2) mst 0.0 3) ultra matrix 0.01 4) subslice 0.0
# /home/cai.507/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
