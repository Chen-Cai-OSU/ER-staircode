# %%
# %matplotlib inline

# %%
# %run helper/intersection.py
# Out:
# 0
# 0 1.01 -54881.35039273248
# line y=1.01*x+-54881.35039273248 instersects with vertical seg (27314.37, -27294.31)(27314.37, -27293.75) at (27314.37, -27293.84). data is null
# Intersect at seg index 109301
# line search takes 0.23993396759033203
# pass segs order test
# Intersect at seg index 109301
# binary search takes 8.177757263183594e-05.
#
# 1 1.01 -41702.2004702574
# line y=1.01*x+-41702.2004702574 instersects with vertical seg (20735.53, -20759.61)(20735.53, -20758.78) at (20735.53, -20759.32). data is null
# Intersect at seg index 83231
# line search takes 0.25582194328308105
# pass segs order test
# Intersect at seg index 83231
# binary search takes 6.556510925292969e-05.
#
# 2 1.01 -43599.49021420038
# line y=1.01*x+-43599.49021420038 instersects with horizonal seg (21680.92, -21701.43)(21681.38, -21701.43) at (21681.25, -21701.43). data is null
# Intersect at seg index 86984
# line search takes 0.23789048194885254
# pass segs order test
# Intersect at seg index 86984
# ...

# %%
# %run I_x/noise.py  --viz_pts --viz_sc --n 50 --n_subsets 50 --line_a 1.01 --line_b -3.5 --scale 10
# Out:
#  ave dist for euclidean is 12.501944229617163
# **************************************************
# Finish computing 50 msts in 0.049
# {0: {'type1': array([[4.3635493 , 2.21365423]]), 'type2': None}, 1: {'type1': array([[4.28226912, 6.77173721],
#        [4.31635399, 5.55445324],
#        [4.34897837, 3.4223082 ],
#        [4.35441173, 2.02138261]]), 'type2': array([[4.31635399, 6.77173721],
#        [4.34897837, 5.55445324],
#        [4.35441173, 3.4223082 ]])}, 2: {'type1': array([[4.07893819, 8.13109365],
#        [4.10970195, 7.58398814],
#        [4.17846383, 7.03467462],
#        [4.27234349, 6.56288827],
#        [4.3377535 , 4.0669486 ],
#        [4.35905318, 2.54371364]]), 'type2': array([[4.10970195, 8.13109365],
#        [4.17846383, 7.58398814],
#        [4.27234349, 7.03467462],
#        [4.3377535 , 6.56288827],
# ...
