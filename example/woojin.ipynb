# %%
import sys
sys.path.append('../')
# %matplotlib inline

# %%
# function val
# x1(bottom left): 0
# x2(top left): 2
# x3(top right): 1
# x4/x5/x6: 3/4/5

# %%
# %run ../I_x/noise.py --save --viz_ind   --viz_pts --woojin
# Out:
#  ave dist for euclidean is 1.083624156187546
# Finish computing 6 msts in 0.002
#  Save at ./viz/RuiLi/public/image/0
#  Save at ./viz/RuiLi/public/image/1
#  Save at ./viz/RuiLi/public/image/2
#  Save at ./viz/RuiLi/public/image/3
#  Save at ./viz/RuiLi/public/image/4
#  Save at ./viz/RuiLi/public/image/5

# %%
# Out:
# '/home/cai.507/Documents/DeepLearning/Clustering/example'

# %% [markdown]
# ![title](/home/cai.507/Documents/DeepLearning/Clustering/viz/woojin/woojin_switch.png)

# %%
# function val
# x1(bottom left): 0
# x2(top left): 1
# x3(top right): 2
# x4/x5/x6: 3/4/5

# %%
# %run ../I_x/noise.py --save --viz_ind   --viz_pts --woojin --switch
# Out:
#  ave dist for euclidean is 1.083624156187546
# Finish computing 6 msts in 0.002
#  Save at ./viz/RuiLi/public/image/0
#  Save at ./viz/RuiLi/public/image/1
#  Save at ./viz/RuiLi/public/image/2
#  Save at ./viz/RuiLi/public/image/3
#  Save at ./viz/RuiLi/public/image/4
#  Save at ./viz/RuiLi/public/image/5
